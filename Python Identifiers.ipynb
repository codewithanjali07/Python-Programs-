# %% [markdown]
# ##### **Name:** Anjali Chopade
# ##### **Roll_no:** 2013

# %% [markdown]
# # Python Identifiers and Reserved Words

# %% [markdown]
# ## Identifiers example

# %%
a = 10
print(10)
# Out:
# 10

# %%
b = 20 
print(b)
# Out:
# 20

# %% [markdown]
# ## Rule 1 : Allowed Character

# %%
Anjali = 20
print(Anjali)
# Out:
# 20

# %%
Cash = 3000
print(Cash)
# Out:
# 3000

# %%
Arjun = 30
print(Arjun)
# Out:
# 30

# %%
varun = 80000
print(varun)
# Out:
# 80000

# %% [markdown]
# ## Rule 1: Identifiers should not Start With Digit(Not Allowed character)

# %%
123Anjali =  20
print(123Anjali)
# Out:
#   Cell In[5], line 1
#     123Anjali =  20
#       ^
# SyntaxError: invalid decimal literal

# %%
@njali = 30
print(@njali)
# Out:
#   Cell In[6], line 1
#     @njali = 30
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
_abc_abc_ =  33
print(_abc_abc_)
# Out:
# 33

# %%
Total123 = 55
print(Total123)
# Out:
# 55

# %%
 !,$,*,@,first no. add is not allowed character.

# %% [markdown]
# ## Rule 3 : Case Sensitive

# %%
anjali = 10
ANJALI = 20
print(anjali)
print(ANJALI)
# Out:
# 10
# 20

# %%
a = input("Enter your small Name:")
b = input("Enter your Bi Name:")
print(a)
print(b)
# Out:
# Enter your small Name: Anjali
# Enter your Bi Name: ANJALI
# Anjali
# ANJALI

# %% [markdown]
# # Valid and Invalid Identifiers

# %%
# valid identifiers
Anjali12333 = 20
python2python = 30
_xyz_xyz_ = 40

print(Anjali12333)
print(python2python)
print(_xyz_xyz_)
# Out:
# 20
# 30
# 40

# %%
#invalid identifiers
1Varun = 20            # starting la No. aahe
@anjali = 30           # @ aahe
Anjali-Anjali = 40     # - aahe
class anju = 50        # keyword aahe
Anjali Chopade = 60    # space aahe

# %% [markdown]
# # Reserved Keywords

# %%
import keyword

print("Total Rsereved Keyword:",len(keyword.kwlist))
print(keyword.kwlist)
# Out:
# Total Rsereved Keyword: 35
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
if_num = 10
class_name = "A"
for_count = 5

print(if_num)
print(class_name)
print(for_count)
# Out:
# 10
# A
# 5

# %%
a = "True"
print("a:",a)
# Out:
# a: True

# %%
b = "False"
print("b:",b)
# Out:
# b: False

# %%
c = "none"
print("c:",c)
# Out:
# c: none
